# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\Shyam\\Desktop\\pythonprojects\\smsspam.csv',encoding = "ISO-8859-1")
df

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline
import matplotlib.pyplot as plt
# Start with one review:

text = ' '.join(df['Text'])
# Create and generate a word cloud image:
wordcloud = WordCloud(background_color = 'white').generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Word clouds for spam and ham seperately

import pandas as pd
df=pd.read_csv('C:\\Users\\Shyam\\Desktop\\pythonprojects\\smsspam.csv',encoding = "ISO-8859-1")
df

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline
import matplotlib.pyplot as plt
# Start with one review:
df = df[df.Class == 'spam']
text = ' '.join(df['Text'])
# Create and generate a word cloud image:
wordcloud = WordCloud(background_color = 'white').generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Word clouds for spam and ham seperately

import pandas as pd
df=pd.read_csv('C:\\Users\\Shyam\\Desktop\\pythonprojects\\smsspam.csv',encoding = "ISO-8859-1")
df

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline
import matplotlib.pyplot as plt
# Start with one review:
df = df[df.Class == 'ham']
text = ' '.join(df['Text'])
# Create and generate a word cloud image:
wordcloud = WordCloud(background_color = 'white').generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
